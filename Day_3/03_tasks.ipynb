# %% [markdown]
# ### Task 3.1
#
# """
# show how temparature affects the generated text by generating text with a low temperature (e.g., 0.7) and a high temperature (e.g., 1.2) and comparing the results. This will help you understand how temperature controls the randomness of the generated text and how it can be used to produce more creative or more focused outputs.
# """
