# %% [markdown]
# ### Task 5.1
#
# run `tiny/llama` in your collab and ask it, `why is the life of a cat so interesting?` This will help you understand how to use the model and how it generates text based on the input prompt.
