# %% [markdown]
# ### Task 2.1
#
# """
# use gpt2 model to generate text based on the prompt "Once upon a time" with parameters max_length=50 and num_return_sequences=3 and print the output.
# """

# %% [markdown]
# ### Task 2.2
# ```python
# print("\n── 2. Sentiment Classification ──")
#
# classifier = pipeline(
#     "text-classification",
#     model="distilbert-base-uncased-finetuned-sst-2-english",
# )
#
# reviews = [
#
# ]
#
# for review in reviews:
#     result = classifier(review)[0]
#     print(f"  '{review[:55]}…'")
#     print(f"   → Label: {result['label']}, Score: {result['score']:.4f}\n")
#
# """
#
# for the above code give 3 movie reviews in the reviews list and print the output.
#
# """
#
# reviews = [
#     "This movie is absolutely fantastic! I loved every minute of it.",
#     "I was bored to death during this film. Waste of time.",
#     "It was an okay movie. Nothing special, but not bad either."
# ]
# ```

# %% [markdown]
# ### Task 2.3
# """
# find out the different entities in the following text using a named entity recognition model and print the output.
# text = "Apple Inc. is looking at buying U.K. startup for $1 billion."
# """

# %% [markdown]
# ### Task 2.4
# take any random article and summarize it
